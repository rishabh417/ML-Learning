# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
input("Enter your name")
# Out:
# 'rishabh'

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num1 = 56
if num1 > 0:
    print("Positive")
elif num1 < 0:
    print("Negative")
else: 
    print("Zero")
# Out:
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a,b,c = 32,23,56

if(a>b and a>c):
    print("a is largest")
elif(b>c):
    print("b is largest")
else:
    print("c is largest")

print(f"{a} is value of a, {b} is value of b, {c} is value of c")
# Out:
# c is largest
# 32 is value of a, 23 is value of b, 56 is value of c

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num = 10
fn = 1

for i in range(2,num+1):
    fn=fn*i

print(f"factorial of {num} is {fn}")
# Out:
# factorial of 10 is 3628800

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
int = 23
flt = 23.2
str = "rishabh"
bln = False

print(f"int type is {type(int)}, flt type is {type(flt)}, str type is {type(str)}, bln type is {type(bln)}")
# Out:
# int type is <class 'int'>, flt type is <class 'float'>, str type is <class 'str'>, bln type is <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here

a = 12
b = 13
print(f"a is {a}, and b is {b} before swap")
a,b = b,a
print(f"a is {a}, and b is {b} after swap")
# Out:
# a is 12, and b is 13 before swap
# a is 13, and b is 12 after swap

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
cls = 40
frnht = (cls*(9/5))+32
print(frnht)
# Out:
# 104.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
first_name = "Rishabh"
last_name = "Singh"
full_name = first_name+last_name
print(full_name)
# Out:
# RishabhSingh

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
num = 2.3
print(type(num))
# Out:
# <class 'float'>

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = 34
num2 = 20
print(f"{num1} + {num2} is {num1+num2}")
print(f"{num1} - {num2} is {num1-num2}")
print(f"{num1} * {num2} is {num1*num2}")
print(f"{num1} / {num2} is {num1/num2}")
# Out:
# 34 + 20 is 54
# 34 - 20 is 14
# 34 * 20 is 680
# 34 / 20 is 1.7

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

num1 = 12
num2 = 23
print(f"{num1} > {num2} : {num1>num2}")
print(f"{num1} < {num2} : {num1<num2}")
print(f"{num1} != {num2} : {num1!=num2}")
print(f"{num1} == {num2} : {num1==num2}")
# Out:
# 12 > 23 : False
# 12 < 23 : True
# 12 != 23 : True
# 12 == 23 : False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
age = 23
if age>18 and age<60: 
    print("eligible for work")
else:
    print("not eligible for work")
# Out:
# eligible for work

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
print(23**2)
# Out:
# 529

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = 20
rslt ="odd" if num&1 == 1 else "even"
if num&1 == 1:
    print("odd")
else: 
    print("even")
print(rslt)
# Out:
# even
# even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
range_natural_numbers = 10
sum = (range_natural_numbers*(range_natural_numbers+1))/2
print(sum)
# Out:
# 55.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
yr = 2026
is_leap_year = True if (yr%4==0 and yr%100!=0) or (yr%400==0) else False
print(is_leap_year)
# Out:
# False

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str = "name"
rvrs = str[::-1]
print(rvrs)
# Out:
# eman

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str = "cababac"
rvrs = "".join(reversed(str))
print("yes") if str == rvrs else print("no");
# Out:
# yes

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
num_list = [3,2,23,0,9,11]
print(num_list)
print(sorted(num_list))
print(num_list)
# Out:
# [3, 2, 23, 0, 9, 11]
# [0, 2, 3, 9, 11, 23]
# [3, 2, 23, 0, 9, 11]
